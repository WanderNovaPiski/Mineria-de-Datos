# %%
import pandas as pd

# %%
df = pd.read_csv('credit_card.csv')

# %%
print(df)
# Out:
#         nombre_tarjeta       fecha  hora    monto  tipo_tarjeta  intentos_cvv  \
# 0    Leilani F. Lowery  03/07/2019    11  $274.93             1             1
# 1      Nehru S. Acosta  08/06/2019    22  $323.77             3             1
# 2     Rajah G. Trevino  10/22/2019     3  $161.86             2             6
# 3       Xena B. Battle  08/17/2019     5   $54.77             3             5
# 4      Neve Z. Ramirez  03/17/2019    15  $148.12             3             8
# ..                 ...         ...   ...      ...           ...           ...
# 95   Orli Z. Hernandez  10/12/2019    23  $183.13             1             6
# 96  Patricia X. Wooten  01/17/2019     8    $4.24             2             2
# 97    Carlos H. Wilder  08/29/2019     3  $181.11             1             2
# 98      Calista B. Roy  11/18/2018    10   $83.82             1             3
# 99   Rose A. Mcfarland  11/12/2018    16  $290.99             1             4
#
# ...

# %%
df.head(7)
# Out:
#       nombre_tarjeta       fecha  hora    monto  tipo_tarjeta  intentos_cvv  \
# 0  Leilani F. Lowery  03/07/2019    11  $274.93             1             1
# 1    Nehru S. Acosta  08/06/2019    22  $323.77             3             1
# 2   Rajah G. Trevino  10/22/2019     3  $161.86             2             6
# 3     Xena B. Battle  08/17/2019     5   $54.77             3             5
# 4    Neve Z. Ramirez  03/17/2019    15  $148.12             3             8
# 5     Aiko D. Mccray  05/14/2019    16   $33.63             3             3
# 6  Jolie V. Humphrey  08/05/2019     9   $56.11             3             1
#
#    comprador_recurrente  devoluciones  reclamaciones  total_compras  \
# 0                     0           1.0            2.0              3
# 1                     1           1.0            3.0              6
# 2                     0           2.0            2.0              4
# 3                     0           1.0            3.0              2
# ...

# %%
df.tail(6)
# Out:
#         nombre_tarjeta       fecha  hora    monto  tipo_tarjeta  intentos_cvv  \
# 94     Hayden Q. Parks  08/30/2019    15  $121.86             2             7
# 95   Orli Z. Hernandez  10/12/2019    23  $183.13             1             6
# 96  Patricia X. Wooten  01/17/2019     8    $4.24             2             2
# 97    Carlos H. Wilder  08/29/2019     3  $181.11             1             2
# 98      Calista B. Roy  11/18/2018    10   $83.82             1             3
# 99   Rose A. Mcfarland  11/12/2018    16  $290.99             1             4
#
#     comprador_recurrente  devoluciones  reclamaciones  total_compras  \
# 94                     0           2.0            2.0              2
# 95                     1           3.0            3.0              5
# 96                     1           1.0            3.0              5
# 97                     1           2.0            2.0              4
# 98                     1           1.0            1.0              5
# ...

# %%
df.shape
# Out:
# (100, 11)

# %%
print(df.describe())
# Out:
#              hora  tipo_tarjeta  intentos_cvv  comprador_recurrente  \
# count  100.000000    100.000000    100.000000            100.000000
# mean    12.440000      2.500000      4.420000              0.510000
# std      7.221349      1.123666      2.314556              0.502418
# min      0.000000      1.000000      1.000000              0.000000
# 25%      6.000000      1.750000      2.750000              0.000000
# 50%     12.000000      2.500000      4.500000              1.000000
# 75%     19.000000      3.250000      6.000000              1.000000
# max     24.000000      4.000000      8.000000              1.000000
#
#        devoluciones  reclamaciones  total_compras  autorizacion
# count     99.000000      98.000000     100.000000         100.0
# mean       1.868687       2.020408       3.580000           1.0
# std        0.816244       0.799221       1.518771           0.0
# min        1.000000       1.000000       1.000000           1.0
# ...

# %%
df.fillna(0)
# Out:
#         nombre_tarjeta       fecha  hora    monto  tipo_tarjeta  intentos_cvv  \
# 0    Leilani F. Lowery  03/07/2019    11  $274.93             1             1
# 1      Nehru S. Acosta  08/06/2019    22  $323.77             3             1
# 2     Rajah G. Trevino  10/22/2019     3  $161.86             2             6
# 3       Xena B. Battle  08/17/2019     5   $54.77             3             5
# 4      Neve Z. Ramirez  03/17/2019    15  $148.12             3             8
# ..                 ...         ...   ...      ...           ...           ...
# 95   Orli Z. Hernandez  10/12/2019    23  $183.13             1             6
# 96  Patricia X. Wooten  01/17/2019     8    $4.24             2             2
# 97    Carlos H. Wilder  08/29/2019     3  $181.11             1             2
# 98      Calista B. Roy  11/18/2018    10   $83.82             1             3
# 99   Rose A. Mcfarland  11/12/2018    16  $290.99             1             4
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = df.plot(x="hora", y="fecha",kind='scatter',color="green")
